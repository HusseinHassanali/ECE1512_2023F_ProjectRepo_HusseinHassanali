# %% [markdown]
# # Imports and installations

# %%
# General
from google.colab import drive
drive.mount('/content/drive')

import os
import torch

github_repo_url = 'https://github.com/GzyAftermath/DATM.git'
repository_name = github_repo_url.split('/')[-1].split('.')[0]

os.chdir('/content/drive/MyDrive/ECE1512/Project_B/Task2/')  # Change to your desired directory in Google Drive
# !git clone $github_repo_url

os.chdir(repository_name)

# !pip install kornia
# !pip install wandb
# !pip install yacs
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'DATM' already exists and is not an empty directory.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Project Questions

# %%
# train on normal set for benchmark
# %cd /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/buffer
# !python buffer_FTD.py --dataset=MNIST --model=ConvNet --train_epochs=50 --num_experts=1 --save_interval 1 --zca --buffer_path=../buffer_storage/ --data_path=../dataset/ --rho_max=0.01 --rho_min=0.01 --alpha=0.3 --lr_teacher=0.01 --mom=0. --batch_train=25
# Out:
# /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/buffer
# Train ZCA
# 100% 60000/60000 [00:11<00:00, 5132.36it/s]
# Test ZCA
# 100% 10000/10000 [00:01<00:00, 5366.18it/s]
# Hyper-parameters:
#  {'dataset': 'MNIST', 'subset': 'imagenette', 'model': 'ConvNet', 'num_experts': 1, 'lr_teacher': 0.01, 'batch_train': 25, 'batch_real': 256, 'dsa': True, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': '../dataset/', 'buffer_path': '../buffer_storage/', 'train_epochs': 50, 'zca': True, 'decay': False, 'mom': 0.0, 'l2': 0, 'save_interval': 1, 'rho_max': 0.01, 'rho_min': 0.01, 'alpha': 0.3, 'adaptive': True, 'device': 'cuda', 'dsa_param': <utils.utils_gsam.ParamDiffAug object at 0x793540602c50>, 'zca_trans': ZCAWhitening()}
# BUILDING DATASET
# ...

# %%
# generate the synthetic set

# %cd /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill
# !python DATM.py --cfg /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/configs/MNIST/IPC1.yaml
# Out:
# /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill
# CUDNN STATUS: True
# Train ZCA
# 100% 60000/60000 [00:11<00:00, 5168.83it/s]
# Test ZCA
# 100% 10000/10000 [00:01<00:00, 5407.60it/s]
# <class 'kornia.enhance.zca.ZCAWhitening'>
# wandb: Currently logged in as: husseinhassanali52 (ece_1512). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill/wandb/run-20231211_071136-kwjpdtm0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hopeful-gorge-7
# wandb: ⭐️ View project at https://wandb.ai/ece_1512/MNIST
# wandb: 🚀 View run at https://wandb.ai/ece_1512/MNIST/runs/kwjpdtm0
# Hyper-parameters:
# ...

# %%
# evaluate the synthetic set

# %cd /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill
# !python evaluation.py --dataset "MNIST" --lr_dir "/content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill/logged_files/MNIST/1/ConvNet/hopeful-gorge-7/Normal/lr_1000.pt" --data_dir "/content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill/logged_files/MNIST/1/ConvNet/hopeful-gorge-7/Normal/images_1000.pt" --label_dir "/content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill/logged_files/MNIST/1/ConvNet/hopeful-gorge-7/Normal/labels_1000.pt" --zca
# Out:
# /content/drive/MyDrive/ECE1512/Project_B/Task2/DATM/distill
# CUDNN STATUS: True
# Train ZCA
# 100% 60000/60000 [00:11<00:00, 5154.22it/s]
# Test ZCA
# 100% 10000/10000 [00:01<00:00, 5517.22it/s]
# <class 'kornia.enhance.zca.ZCAWhitening'>
# Hyper-parameters:
# ...
